# %% [markdown]
# ### What are Modules?
# - Code libraries in Python.
# - Contain functions for use.
# - Examples:
#
# 1. **Math:** Math ops
# 2. **Random:** Random numbers
# 3. **os:** OS interaction
# 4. **time:** Time tasks

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with SQLite version 3.45.3
# c:\Users\aggar\AppData\Local\Programs\Python\Python312\Lib\pkgutil.py:78: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# c:\Users\aggar\AppData\Local\Programs\Python\Python312\Lib\pkgutil.py:78: FutureWarning: The 'optree.integration' module is deprecated and will be removed in version 0.18.0. Please use 'optree.integrations' instead.
#   __import__(info.name)
# c:\Users\aggar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydantic\experimental\__init__.py:7: PydanticExperimentalWarning: This module is experimental, its contents are subject to change and deprecation.
#   warnings.warn(
# IPython             cProfile            markdown_it         sspicon
# PIL                 calendar            markupsafe          stack_data
# ...

# %% [markdown]
# ### just like <span style="color:red">#include<math.h></span> we have math as a **modul**e in python

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.factorial(5)
# Out:
# 120

# %%
math.ceil(6.3)
# Out:
# 7

# %%
math.floor(6.6)
# Out:
# 6

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
math.log10(2)
# Out:
# 0.3010299956639812

# %% [markdown]
# ### we also have **random** module

# %%
import random

# %%
list = [1, 2, 3, 4, 5]
random.shuffle(list)
list
# Out:
# [3, 2, 5, 1, 4]

# %%
random.randint(1,100)
# Out:
# 84

# %% [markdown]
# ### we also have **time** module

# %%
import time

# %%
#returns the current time in seconds from Jan 1, 1970, till now
time.time()
# Out:
# 1775372986.719118

# %%
# CURRENT TIME
time.ctime()
# Out:
# 'Sun Apr  5 12:40:13 2026'

# %%
# SLEEP(value) -> gives a delay between the lines of code executing
print("hello")
time.sleep(2)
print("world!")
# Out:
# hello
# world!

# %% [markdown]
# ### OS module

# %%
import os

# %%
# GETS THE CURRENT WORKING DIRECTORY
os.getcwd()
# Out:
# 'c:\\Users\\aggar\\Desktop\\Python Programming\\Python Modules'

# %%
# RETURNS THE FILES IN THE CURRENT DIRECTORY
os.listdir()
# Out:
# ['modules.ipynb']
