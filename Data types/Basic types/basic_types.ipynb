# %% [markdown]
# ##### Python supports 3 categories of data types:
# - <p style="color:lightblue;">basic types (int, float, string, complex, boolean)</p>
# - <p style="color:lightblue;">container types (list, tuple, sets and dictionary)</p>
# - <p style="color:lightblue;">User defines types (classes)</p>

# %%
#integer
print(4)
# Out:
# 4

# %%
#float
print(4.5)
print(1.7e45)
# Out:
# 4.5
# 1.7e+45

# %%
#string
print('hello world!')
print("hello world!")
print("""hello world!""")
# Out:
# hello world!
# hello world!
# hello world!
