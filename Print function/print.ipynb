# %%
#simple print function
print("Hello World!")
# Out:
# Hello World!

# %%
#we can print different things together using the print function
print("hey", "how", "are","you")
# Out:
# hey how are you

# %%
#we can also print different data type
print("hey", 5.6, 5)
# Out:
# hey 5.6 5

# %% [markdown]
# ##### press shift tab to access the documentation

# %%
print("hey", "how", "are","you", sep='-')
# Out:
# hey-how-are-you

# %%
print("hey", "how", "are","you", sep='/')
# Out:
# hey/how/are/you

# %% [markdown]
# ##### we also have end inside the print which's default value is: <p style="color:red;">end = '\n'</p>

# %%
print("hello", end=' ')
print("world")
# Out:
# hello world
