# %% [markdown]
# ### 1. print

# %%
print("hello world!")
# Out:
# hello world!

# %% [markdown]
# ### 2. input

# %%
input("Enter your name:")
# Out:
# 'John'

# %% [markdown]
# ### 3. type

# %%
print(type(23))
print(type('hello'))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ### 4. type conversion

# %%
int('5')
# already discussed under type conversions
# Out:
# 5

# %% [markdown]
# ### 5. abs

# %%
abs(-4)
# Out:
# 4

# %% [markdown]
# ### 6. pow

# %%
pow(2, 3)
# Out:
# 8

# %% [markdown]
# ### 7. min/max

# %%
list = [2, 1, 3, 0]
print(min(list))
print(max(list))
print(min('hellow'))
print(max('hellow'))
# Out:
# 0
# 3
# e
# w

# %% [markdown]
# ### 8. round

# %%
c = 22/7
print(c)
round(c)
# Out:
# 3.142857142857143
# 3

# %% [markdown]
# ### 9. divmod

# %%
# Return the tuple (x//y, x%y). Invariant: div*y + mod == x.

divmod(22,7)
# x//y = 3
# x%y = 1
# Out:
# (3, 1)

# %% [markdown]
# ### 10. address of a variable in the computer. (different for every system)

# %%
a = 3
id(a)
# Out:
# 140716160707064

# %% [markdown]
# ### 11. ASCII Values

# %%
ord('A')
# Out:
# 65

# %% [markdown]
# ### 12. len - tells us the length of the iterable

# %%
list = [1, 2, 3, 4]
message = 'Hello'
print(len(list))
print(len(message))
# Out:
# 4
# 5

# %% [markdown]
# ### 13. sum

# %%
list = [1, 2, 3, 5]
sum(list)
# Out:
# 11

# %% [markdown]
# ### 14. help -> to read documentation of any function to understand it

# %%
help('sum')
# Out:
# Help on built-in function sum in module builtins:
#
# sum(iterable, /, start=0)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.

# %%
help('ord')
# Out:
# Help on built-in function ord in module builtins:
#
# ord(c, /)
#     Return the Unicode code point for a one-character string.

# %%
help('len')
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.
